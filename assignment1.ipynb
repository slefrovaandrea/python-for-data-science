# %% [markdown]
# # Assignment 1
# - deadline: 15.10.2025
# - you will learn: how to submit solutions
# - task: run all the cells below, add another cell where you print your GitHub username, commit and push the changes to your repository

# %%
print("2+1 = ", 2+1)
# Out:
# 2+1 =  3

# %%
print("slefrovaandrea")
# Out:
# slefrovaandrea
